# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    customer_id  age  annual_income  months_active  avg_monthly_spend  \
# 0        33554   53  100473.211709             63         121.430565
# 1         9428   54   54730.644845             67         572.552674
# 2          200   44   58268.121079             57         266.593896
# 3        12448   54   64829.795654             40         691.452358
# 4        39490   28   27431.467873             15         832.664792
#
#    purchase_frequency  avg_order_value  discount_usage_rate  return_rate  \
# 0            0.817268        66.820403             0.117256     0.023144
# 1            3.176551       137.087449             0.261647     0.429054
# 2            2.713168        71.796888             0.284785     0.011854
# 3            5.553977       105.501185             0.104832     0.399686
# 4            1.348389       354.568534             0.409204     0.039517
#
#    browsing_time_minutes  support_interactions payment_method      region  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1021 entries, 0 to 1020
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            1021 non-null   int64
#  1   age                    1021 non-null   int64
#  2   annual_income          1021 non-null   float64
#  3   months_active          1021 non-null   int64
#  4   avg_monthly_spend      1021 non-null   float64
#  5   purchase_frequency     1021 non-null   float64
#  6   avg_order_value        1021 non-null   float64
#  7   discount_usage_rate    1021 non-null   float64
#  8   return_rate            1021 non-null   float64
#  9   browsing_time_minutes  1021 non-null   float64
#  10  support_interactions   1021 non-null   float64
#  11  payment_method         1021 non-null   str
#  12  region                 1021 non-null   str
#  13  customer_segment       1021 non-null   str
#  14  total_spend            1021 non-null   float64
# ...

# %%
df.drop(columns=['customer_id'],inplace=True)

# %%
df.head()
# Out:
#    age  annual_income  months_active  avg_monthly_spend  purchase_frequency  \
# 0   53  100473.211709             63         121.430565            0.817268
# 1   54   54730.644845             67         572.552674            3.176551
# 2   44   58268.121079             57         266.593896            2.713168
# 3   54   64829.795654             40         691.452358            5.553977
# 4   28   27431.467873             15         832.664792            1.348389
#
#    avg_order_value  discount_usage_rate  return_rate  browsing_time_minutes  \
# 0        66.820403             0.117256     0.023144              77.298393
# 1       137.087449             0.261647     0.429054              92.132565
# 2        71.796888             0.284785     0.011854             155.194768
# 3       105.501185             0.104832     0.399686             113.917756
# 4       354.568534             0.409204     0.039517              50.123656
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'annual_income', 'months_active', 'avg_monthly_spend',
#        'purchase_frequency', 'avg_order_value', 'discount_usage_rate',
#        'return_rate', 'browsing_time_minutes', 'support_interactions',
#        'payment_method', 'region', 'customer_segment', 'total_spend',
#        'engagement_score'],
#       dtype='str')

# %%
numerical_data=['age', 'annual_income', 'months_active', 'avg_monthly_spend',
        'avg_order_value', 'discount_usage_rate',
       'return_rate', 'browsing_time_minutes', 'support_interactions','total_spend',
       'engagement_score']
categorical_data=['payment_method','customer_segment','region']    
y=['purchase_frequency']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
numeric_pipeline=Pipeline(steps=[('scaling',StandardScaler())])
categorical_pipeline=Pipeline(steps=[('encode',OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer

# %%
features=ColumnTransformer(transformers=[('num',numeric_pipeline,numerical_data),('cat',categorical_pipeline,categorical_data)])

# %%
features
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaling',
#                                                   StandardScaler())]),
#                                  ['age', 'annual_income', 'months_active',
#                                   'avg_monthly_spend', 'avg_order_value',
#                                   'discount_usage_rate', 'return_rate',
#                                   'browsing_time_minutes',
#                                   'support_interactions', 'total_spend',
#                                   'engagement_score']),
#                                 ('cat',
#                                  Pipeline(steps=[('encode',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['payment_method', 'customer_segment',
#                                   'region'])])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=Pipeline(steps=[('features',features),('Regression',LinearRegression())])

# %%
model
# Out:
# Pipeline(steps=[('features',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   ['age', 'annual_income',
#                                                    'months_active',
#                                                    'avg_monthly_spend',
#                                                    'avg_order_value',
#                                                    'discount_usage_rate',
#                                                    'return_rate',
#                                                    'browsing_time_minutes',
#                                                    'support_interactions',
#                                                    'total_spend',
#                                                    'engagement_score']),
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns=y)

# %%
Y=df['purchase_frequency']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('features',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   ['age', 'annual_income',
#                                                    'months_active',
#                                                    'avg_monthly_spend',
#                                                    'avg_order_value',
#                                                    'discount_usage_rate',
#                                                    'return_rate',
#                                                    'browsing_time_minutes',
#                                                    'support_interactions',
#                                                    'total_spend',
#                                                    'engagement_score']),
# ...

# %%
y_predict=model.predict(x_test)

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x=y_test, y=y_predict)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")

plt.show()
